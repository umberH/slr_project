# %%
import featuretools as ft

# %%
data = ft.demo.load_mock_customer()

customers_df = data["customers"]
customers_df
# Out:
#    customer_id zip_code           join_date   birthday
# 0            1    60091 2011-04-17 10:48:33 1994-07-18
# 1            2    13244 2012-04-15 23:31:04 1986-08-18
# 2            3    13244 2011-08-13 15:42:34 2003-11-21
# 3            4    60091 2011-04-08 20:08:14 2006-08-15
# 4            5    60091 2010-07-17 05:27:50 1984-07-28

# %%
sessions_df = data["sessions"]
sessions_df.sample(5)
# Out:
#     session_id  customer_id   device       session_start
# 13          14            1   tablet 2014-01-01 03:28:00
# 6            7            3   tablet 2014-01-01 01:39:40
# 1            2            5   mobile 2014-01-01 00:17:20
# 28          29            1   mobile 2014-01-01 07:10:05
# 24          25            3  desktop 2014-01-01 05:59:40

# %%
transactions_df = data["transactions"]
transactions_df.sample(5)
# Out:
#      transaction_id  session_id    transaction_time product_id  amount
# 74              232           5 2014-01-01 01:20:10          1  139.20
# 231              27          17 2014-01-01 04:10:15          2   90.79
# 434              36          31 2014-01-01 07:50:10          3   62.35
# 420              56          30 2014-01-01 07:35:00          3   72.70
# 54              444           4 2014-01-01 00:58:30          4   43.59

# %%
dataframes = {
    "customers": (customers_df, "customer_id"),
    "sessions": (sessions_df, "session_id", "session_start"),
    "transactions": (transactions_df, "transaction_id", "transaction_time"),
}

# %%
relationships = [
    ("sessions", "session_id", "transactions", "session_id"),
    ("customers", "customer_id", "sessions", "customer_id"),
]

# %%
feature_matrix_customers, features_defs = ft.dfs(
    dataframes=dataframes,
    relationships=relationships,
    target_dataframe_name="customers",
)
feature_matrix_customers
# Out:
#              zip_code  COUNT(sessions) MODE(sessions.device)  \
# customer_id
# 1               60091                8                mobile
# 2               13244                7               desktop
# 3               13244                6               desktop
# 4               60091                8                mobile
# 5               60091                6                mobile
#
#              NUM_UNIQUE(sessions.device)  COUNT(transactions)  \
# customer_id
# 1                                      3                  126
# 2                                      3                   93
# 3                                      3                   93
# 4                                      3                  109
# 5                                      3                   79
#
#              MAX(transactions.amount)  MEAN(transactions.amount)  \
# customer_id
# 1                              139.43                  71.631905
# 2                              146.81                  77.422366
# 3                              149.15                  67.060430
# 4                              149.95                  80.070459
# 5                              149.02                  80.375443
#
#              MIN(transactions.amount) MODE(transactions.product_id)  \
# customer_id
# 1                                5.81                             4
# 2                                8.73                             4
# 3                                5.89                             1
# 4                                5.73                             2
# 5                                7.55                             5
#
#              NUM_UNIQUE(transactions.product_id)  ...  \
# customer_id                                       ...
# 1                                              5  ...
# 2                                              5  ...
# 3                                              5  ...
# 4                                              5  ...
# 5                                              5  ...
#
#              STD(sessions.SKEW(transactions.amount))  \
# customer_id
# 1                                           0.589386
# 2                                           0.509798
# 3                                           0.429374
# 4                                           0.387884
# 5                                           0.415426
#
#              STD(sessions.SUM(transactions.amount))  \
# customer_id
# 1                                        279.510713
# 2                                        251.609234
# 3                                        219.021420
# 4                                        235.992478
# 5                                        402.775486
#
#              SUM(sessions.MAX(transactions.amount))  \
# customer_id
# 1                                           1057.97
# 2                                            931.63
# 3                                            847.63
# 4                                           1157.99
# 5                                            839.76
#
#             SUM(sessions.MEAN(transactions.amount))  \
# customer_id
# 1                                        582.193117
# 2                                        548.905851
# 3                                        405.237462
# 4                                        649.657515
# 5                                        472.231119
#
#             SUM(sessions.MIN(transactions.amount))  \
# customer_id
# 1                                            78.59
# 2                                           154.60
# 3                                            66.21
# 4                                           131.51
# 5                                            86.49
#
#             SUM(sessions.NUM_UNIQUE(transactions.product_id))  \
# customer_id
# 1                                                        40.0
# 2                                                        35.0
# 3                                                        29.0
# 4                                                        37.0
# 5                                                        30.0
#
#             SUM(sessions.SKEW(transactions.amount))  \
# customer_id
# 1                                         -0.476122
# 2                                         -0.277640
# 3                                          2.286086
# 4                                          0.002764
# 5                                          0.014384
#
#             SUM(sessions.STD(transactions.amount))  \
# customer_id
# 1                                       312.745952
# 2                                       258.700528
# 3                                       257.299895
# 4                                       356.125829
# 5                                       259.873954
#
#             MODE(transactions.sessions.device)  \
# customer_id
# 1                                       mobile
# 2                                      desktop
# 3                                      desktop
# 4                                       mobile
# 5                                       mobile
#
#             NUM_UNIQUE(transactions.sessions.device)
# customer_id
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
# 5                                                  3
#
# [5 rows x 75 columns]

# %%
feature_matrix_sessions, features_defs = ft.dfs( dataframes=dataframes, relationships=relationships, target_dataframe_name="sessions"
)
feature_matrix_sessions.head(5)
# Out:
# c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\featuretools\entityset\entityset.py:754: UserWarning: A Woodwork-initialized DataFrame was provided, so the following parameters were ignored: index
#   warnings.warn(
# c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\featuretools\entityset\entityset.py:754: UserWarning: A Woodwork-initialized DataFrame was provided, so the following parameters were ignored: index, time_index
#   warnings.warn(
#             customer_id   device  COUNT(transactions)  \
# session_id
# 1                     2  desktop                   16
# 2                     5   mobile                   10
# 3                     4   mobile                   15
# 4                     1   mobile                   25
# 5                     4   mobile                   11
#
#             MAX(transactions.amount)  MEAN(transactions.amount)  \
# session_id
# 1                             141.66                  76.813125
# 2                             135.25                  74.696000
# 3                             147.73                  88.600000
# 4                             129.00                  64.557200
# 5                             139.20                  70.638182
#
#             MIN(transactions.amount) MODE(transactions.product_id)  \
# session_id
# 1                              20.91                             3
# 2                               9.32                             5
# 3                               8.70                             1
# 4                               6.29                             5
# 5                               7.43                             5
#
#             NUM_UNIQUE(transactions.product_id)  SKEW(transactions.amount)  \
# session_id
# 1                                             5                   0.295458
# 2                                             5                  -0.160550
# 3                                             5                  -0.324012
# 4                                             5                   0.234349
# 5                                             5                   0.336381
#
#             STD(transactions.amount)  ...  customers.STD(transactions.amount)  \
# session_id                            ...
# 1                          41.600976  ...                           37.705178
# 2                          45.893591  ...                           44.095630
# 3                          46.240016  ...                           45.068765
# 4                          40.187205  ...                           40.442059
# 5                          48.918663  ...                           45.068765
#
#            customers.SUM(transactions.amount) customers.DAY(birthday)  \
# session_id
# 1                                     7200.28                      18
# 2                                     6349.66                      28
# 3                                     8727.68                      15
# 4                                     9025.62                      18
# 5                                     8727.68                      15
#
#            customers.DAY(join_date) customers.MONTH(birthday)  \
# session_id
# 1                                15                         8
# 2                                17                         7
# 3                                 8                         8
# 4                                17                         7
# 5                                 8                         8
#
#             customers.MONTH(join_date) customers.WEEKDAY(birthday)  \
# session_id
# 1                                    4                           0
# 2                                    7                           5
# 3                                    4                           1
# 4                                    4                           0
# 5                                    4                           1
#
#            customers.WEEKDAY(join_date) customers.YEAR(birthday)  \
# session_id
# 1                                     6                     1986
# 2                                     5                     1984
# 3                                     4                     2006
# 4                                     6                     1994
# 5                                     4                     2006
#
#            customers.YEAR(join_date)
# session_id
# 1                               2012
# 2                               2010
# 3                               2011
# 4                               2011
# 5                               2011
#
# [5 rows x 44 columns]

# %%
feature = features_defs[18]
feature
# Out:
# <Feature: MODE(transactions.WEEKDAY(transaction_time))>

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\ambreen.hanif\github\slr_project\venv_pycaret_3.8\lib\site-packages (0.20.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
ft.graph_feature(feature)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\graphviz\backend\execute.py:79, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      78         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 79     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      80 else:
#
# File c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\graphviz\backend\execute.py:99, in _run_input_lines(cmd, input_lines, kwargs)
#      98 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 99     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#     101     stdin_write = popen.stdin.write
#
# File ~\AppData\Local\Programs\Python\Python38\lib\subprocess.py:854, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     851             self.stderr = io.TextIOWrapper(self.stderr,
#     852                     encoding=encoding, errors=errors)
# --> 854     self._execute_child(args, executable, preexec_fn, close_fds,
#     855                         pass_fds, cwd, env,
#     856                         startupinfo, creationflags, shell,
#     857                         p2cread, p2cwrite,
#     858                         c2pread, c2pwrite,
#     859                         errread, errwrite,
#     860                         restore_signals, start_new_session)
#     861 except:
#     862     # Cleanup if the child failed starting.
#
# File ~\AppData\Local\Programs\Python\Python38\lib\subprocess.py:1307, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1306 try:
# -> 1307     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1308                              # no special security
#    1309                              None, None,
#    1310                              int(not close_fds),
#    1311                              creationflags,
#    1312                              env,
#    1313                              cwd,
#    1314                              startupinfo)
#    1315 finally:
#    1316     # Child is launched. Close the parent's copy of those pipe
#    1317     # handles that only the child should have open.  You need
#    (...)
#    1320     # pipe will not close when the child process exits and the
#    1321     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# File c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\featuretools\utils\plot_utils.py:13, in check_graphviz()
#      12 try:
# ---> 13     graphviz.Digraph().pipe(format="svg")
#      14 except graphviz.backend.ExecutableNotFound:
#
# File c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\graphviz\piping.py:104, in Pipe.pipe(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#      63 """Return the source piped through the Graphviz layout command.
#      64
#      65 Args:
#    (...)
#     102     '<?xml version='
#     103 """
# --> 104 return self._pipe_legacy(format,
#     105                          renderer=renderer,
#     106                          formatter=formatter,
#     107                          neato_no_op=neato_no_op,
#     108                          quiet=quiet,
#     109                          engine=engine,
#     110                          encoding=encoding)
#
# File c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\graphviz\piping.py:121, in Pipe._pipe_legacy(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     112 @_tools.deprecate_positional_args(supported_number=2)
#     113 def _pipe_legacy(self,
#     114                  format: typing.Optional[str] = None,
#    (...)
#     119                  engine: typing.Optional[str] = None,
#     120                  encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
# --> 121     return self._pipe_future(format,
#     122                              renderer=renderer,
#     123                              formatter=formatter,
#     124                              neato_no_op=neato_no_op,
#     125                              quiet=quiet,
#     126                              engine=engine,
#     127                              encoding=encoding)
#
# File c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\graphviz\piping.py:161, in Pipe._pipe_future(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     160         return raw.decode(encoding)
# --> 161 return self._pipe_lines(*args, input_encoding=self.encoding, **kwargs)
#
# File c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\graphviz\backend\piping.py:161, in pipe_lines(engine, format, input_lines, input_encoding, renderer, formatter, neato_no_op, quiet)
#     159 kwargs = {'input_lines': (line.encode(input_encoding) for line in input_lines)}
# --> 161 proc = execute.run_check(cmd, capture_output=True, quiet=quiet, **kwargs)
#     162 return proc.stdout
#
# File c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\graphviz\backend\execute.py:84, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      83 if e.errno == errno.ENOENT:
# ---> 84     raise ExecutableNotFound(cmd) from e
#      85 raise
#
# ExecutableNotFound: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# c:\Users\ambreen.hanif\Github\slr_project\experiments\hackathon_test.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ambreen.hanif/Github/slr_project/experiments/hackathon_test.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> ft.graph_feature(feature)
#
# File c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\featuretools\feature_base\feature_visualizer.py:51, in graph_feature(feature, to_file, description, **kwargs)
#      35 def graph_feature(feature, to_file=None, description=False, **kwargs):
#      36     """Generates a feature lineage graph for the given feature
#      37
#      38     Args:
#    (...)
#      49         graphviz.Digraph : Graph object that can directly be displayed in Jupyter notebooks.
#      50     """
# ---> 51     graphviz = check_graphviz()
#      52     format_ = get_graphviz_format(graphviz=graphviz, to_file=to_file)
#      54     # Initialize a new directed graph
#
# File c:\Users\ambreen.hanif\Github\slr_project\venv_pycaret_3.8\lib\site-packages\featuretools\utils\plot_utils.py:15, in check_graphviz()
#      13     graphviz.Digraph().pipe(format="svg")
#      14 except graphviz.backend.ExecutableNotFound:
# ---> 15     raise RuntimeError(
#      16         "To plot entity sets, a graphviz backend is required.\n"
#      17         + "Install the backend using one of the following commands:\n"
#      18         + "  Mac OS: brew install graphviz\n"
#      19         + "  Linux (Ubuntu): $ sudo apt install graphviz\n"
#      20         + "  Windows (conda): conda install -c conda-forge python-graphviz\n"
#      21         + "  Windows (pip): pip install graphviz\n"
#      22         + "  Windows (EXE required if graphviz was installed via pip): https://graphviz.org/download/#windows"
#      23         + "  For more details visit: https://featuretools.alteryx.com/en/stable/install.html#installing-graphviz",
#      24     )
#      25 return graphviz
#
# RuntimeError: To plot entity sets, a graphviz backend is required.
# Install the backend using one of the following commands:
#   Mac OS: brew install graphviz
#   Linux (Ubuntu): $ sudo apt install graphviz
#   Windows (conda): conda install -c conda-forge python-graphviz
#   Windows (pip): pip install graphviz
#   Windows (EXE required if graphviz was installed via pip): https://graphviz.org/download/#windows  For more details visit: https://featuretools.alteryx.com/en/stable/install.html#installing-graphviz

# %%
ft.describe_feature(feature)
# Out:
# 'The most frequently occurring value of the day of the week of the "transaction_time" of all instances of "transactions" for each "session_id" in "sessions".'
